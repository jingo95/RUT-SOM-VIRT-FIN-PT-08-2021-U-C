# %%
# Import libraries and dependencies
import pandas as pd
from pathlib import Path

# %%
# Set the path
file_path = Path('../Resources/loans.csv')

# Read in the CSV as a DataFrame
loans_csv = pd.read_csv(file_path)

# %%
# Retrive rows with index 0 up to 10 (not including)
loans_csv.iloc[0:10]
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv       term  int_rate  installment  \
# 0      10000        10000            10000  36 months    0.1033       324.23
# 1       4000         4000             4000  36 months    0.2340       155.68
# 2       5000         5000             5000  36 months    0.1797       180.69
# 3       9600         9600             9600  36 months    0.1298       323.37
# 4       2500         2500             2500  36 months    0.1356        84.92
# 5      30000        30000            30000  60 months    0.1894       777.23
# 6      23000        23000            23000  60 months    0.2089       620.81
# 7      32075        32075            32075  60 months    0.1180       710.26
# 8       8000         8000             8000  36 months    0.2340       311.35
# 9      10000        10000            10000  60 months    0.1992       264.50
#
#   grade sub_grade           emp_title emp_length home_ownership  annual_inc  \
# 0     B        B1                 NaN   < 1 year       MORTGAGE    280000.0
# 1     E        E1            Security    3 years           RENT     90000.0
# 2     D        D1      Administrative    6 years       MORTGAGE     59280.0
# 3     B        B5                 NaN        NaN       MORTGAGE     35704.0
# 4     C        C1                Chef  10+ years           RENT     55000.0
# 5     D        D2         Postmaster   10+ years       MORTGAGE     90000.0
# 6     D        D4            Operator    5 years           RENT     68107.0
# 7     B        B4  Nursing Supervisor  10+ years       MORTGAGE    150000.0
# 8     E        E1             Manager  10+ years            OWN     43000.0
# 9     D        D3    Material Handler  10+ years       MORTGAGE     80000.0
#
#   verification_status issue_d loan_status pymnt_plan             purpose
# 0        Not Verified  Dec-18     Current          n  debt_consolidation
# 1     Source Verified  Dec-18     Current          n  debt_consolidation
# 2     Source Verified  Dec-18     Current          n  debt_consolidation
# 3        Not Verified  Dec-18     Current          n    home_improvement
# 4        Not Verified  Dec-18     Current          n  debt_consolidation
# 5     Source Verified  Dec-18     Current          n  debt_consolidation
# 6     Source Verified  Dec-18     Current          n  debt_consolidation
# 7        Not Verified  Dec-18     Current          n         credit_card
# 8     Source Verified  Dec-18     Current          n  debt_consolidation
# 9        Not Verified  Dec-18     Current          n  debt_consolidation

# %%
# Describe summary statistics for csv data
loans_csv.describe(include='all')
# Out:
#            loan_amnt   funded_amnt  funded_amnt_inv       term     int_rate  \
# count    3786.000000   3786.000000      3786.000000       3786  3786.000000
# unique           NaN           NaN              NaN          2          NaN
# top              NaN           NaN              NaN  36 months          NaN
# freq             NaN           NaN              NaN       2603          NaN
# mean    16112.856577  16112.856577     16109.627575        NaN     0.126338
# std     10385.138405  10385.138405     10387.371112        NaN     0.048185
# min      1000.000000   1000.000000       750.000000        NaN     0.060000
# 25%      8000.000000   8000.000000      8000.000000        NaN     0.081900
# 50%     14000.000000  14000.000000     14000.000000        NaN     0.118000
# 75%     22000.000000  22000.000000     22000.000000        NaN     0.150200
# max     40000.000000  40000.000000     40000.000000        NaN     0.307500
#
#         installment grade sub_grade emp_title emp_length home_ownership  \
# count   3786.000000  3786      3786      3230       3508           3786
# unique          NaN     6        27      2306         11              4
# top             NaN     A        A4   Teacher  10+ years       MORTGAGE
# freq            NaN  1213       362        86       1113           1946
# mean     462.116075   NaN       NaN       NaN        NaN            NaN
# std      286.093587   NaN       NaN       NaN        NaN            NaN
# min       30.640000   NaN       NaN       NaN        NaN            NaN
# 25%      249.080000   NaN       NaN       NaN        NaN            NaN
# 50%      389.125000   NaN       NaN       NaN        NaN            NaN
# 75%      622.680000   NaN       NaN       NaN        NaN            NaN
# max     1409.050000   NaN       NaN       NaN        NaN            NaN
#
#           annual_inc verification_status issue_d loan_status pymnt_plan  \
# count   3.786000e+03                3786    3786        3786       3786
# unique           NaN                   3       1           5          1
# top              NaN        Not Verified  Dec-18     Current          n
# freq             NaN                1851    3786        3615       3786
# mean    8.559789e+04                 NaN     NaN         NaN        NaN
# std     6.370011e+04                 NaN     NaN         NaN        NaN
# min     0.000000e+00                 NaN     NaN         NaN        NaN
# 25%     5.000000e+04                 NaN     NaN         NaN        NaN
# 50%     7.048764e+04                 NaN     NaN         NaN        NaN
# 75%     1.020000e+05                 NaN     NaN         NaN        NaN
# max     1.120000e+06                 NaN     NaN         NaN        NaN
#
#                    purpose
# count                 3786
# unique                  13
# top     debt_consolidation
# freq                  2039
# mean                   NaN
# std                    NaN
# min                    NaN
# 25%                    NaN
# 50%                    NaN
# 75%                    NaN
# max                    NaN

# %%
filtered_df = loans_csv.iloc[:,[0,3,4,8,11,16]]
filtered_df.head()
# Out:
#    loan_amnt       term  int_rate       emp_title  annual_inc  \
# 0      10000  36 months    0.1033             NaN    280000.0
# 1       4000  36 months    0.2340        Security     90000.0
# 2       5000  36 months    0.1797  Administrative     59280.0
# 3       9600  36 months    0.1298             NaN     35704.0
# 4       2500  36 months    0.1356            Chef     55000.0
#
#               purpose
# 0  debt_consolidation
# 1  debt_consolidation
# 2  debt_consolidation
# 3    home_improvement
# 4  debt_consolidation

# %%
filtered_df['term'].value_counts()
# Out:
# 36 months    2603
# 60 months    1183
# Name: term, dtype: int64

# %%
filtered_df.loc[filtered_df['term'] == '36 months']
# Out:
#       loan_amnt       term  int_rate                             emp_title  \
# 0         10000  36 months    0.1033                                   NaN
# 1          4000  36 months    0.2340                              Security
# 2          5000  36 months    0.1797                        Administrative
# 3          9600  36 months    0.1298                                   NaN
# 4          2500  36 months    0.1356                                  Chef
# ...         ...        ...       ...                                   ...
# 3779      40000  36 months    0.1180                 Biomedical Technician
# 3780       7500  36 months    0.0646                       Doctoral Fellow
# 3781      40000  36 months    0.1180  Director of Training and Development
# 3783      12550  36 months    0.0702                    Heavy Truck Driver
# 3784       8000  36 months    0.0702                                   NaN
#
#       annual_inc             purpose
# 0       280000.0  debt_consolidation
# 1        90000.0  debt_consolidation
# 2        59280.0  debt_consolidation
# 3        35704.0    home_improvement
# 4        55000.0  debt_consolidation
# ...          ...                 ...
# 3779    100000.0  debt_consolidation
# 3780    650000.0  debt_consolidation
# 3781     75000.0  debt_consolidation
# 3783     80000.0    home_improvement
# 3784     26000.0  debt_consolidation
#
# [2603 rows x 6 columns]

# %%
filtered_df.loc[filtered_df['term'] == '36 months', 'term'] = '3 years'
# filtered_df
# Out:
# /Users/aordorica/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
filtered_df['term'].value_counts()
# Out:
# 3 years      2603
# 60 months    1183
# Name: term, dtype: int64

# %%
filtered_df = loans_csv.iloc[:,[0,3,4,8,11,16]]
filtered_df.head()
# Out:
#    loan_amnt       term  int_rate       emp_title  annual_inc  \
# 0      10000  36 months    0.1033             NaN    280000.0
# 1       4000  36 months    0.2340        Security     90000.0
# 2       5000  36 months    0.1797  Administrative     59280.0
# 3       9600  36 months    0.1298             NaN     35704.0
# 4       2500  36 months    0.1356            Chef     55000.0
#
#               purpose
# 0  debt_consolidation
# 1  debt_consolidation
# 2  debt_consolidation
# 3    home_improvement
# 4  debt_consolidation

# %%
term_df = filtered_df.loc[filtered_df['term'] == '36 months'].copy()
term_df
# term_df.loc[term_df['term'] == '36 months', 'term'] = '3 years'
# Out:
#       loan_amnt       term  int_rate                             emp_title  \
# 0         10000  36 months    0.1033                                   NaN
# 1          4000  36 months    0.2340                              Security
# 2          5000  36 months    0.1797                        Administrative
# 3          9600  36 months    0.1298                                   NaN
# 4          2500  36 months    0.1356                                  Chef
# ...         ...        ...       ...                                   ...
# 3779      40000  36 months    0.1180                 Biomedical Technician
# 3780       7500  36 months    0.0646                       Doctoral Fellow
# 3781      40000  36 months    0.1180  Director of Training and Development
# 3783      12550  36 months    0.0702                    Heavy Truck Driver
# 3784       8000  36 months    0.0702                                   NaN
#
#       annual_inc             purpose
# 0       280000.0  debt_consolidation
# 1        90000.0  debt_consolidation
# 2        59280.0  debt_consolidation
# 3        35704.0    home_improvement
# 4        55000.0  debt_consolidation
# ...          ...                 ...
# 3779    100000.0  debt_consolidation
# 3780    650000.0  debt_consolidation
# 3781     75000.0  debt_consolidation
# 3783     80000.0    home_improvement
# 3784     26000.0  debt_consolidation
#
# [2603 rows x 6 columns]

# %%
filtered_df['term'].value_counts()
# Out:
# 36 months    2603
# 60 months    1183
# Name: term, dtype: int64

# %%
term_df['emp_title'].value_counts()
# Out:
# Teacher                 58
# Manager                 48
# Supervisor              19
# General Manager         17
# Driver                  15
#                         ..
# Assistant manager        1
# schools safety agent     1
# Store Manager            1
# Senior HRIS Analyst      1
# Heavy Truck Driver       1
# Name: emp_title, Length: 1613, dtype: int64
